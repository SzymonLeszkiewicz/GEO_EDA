# %%
import os

import datasets
import pandas as pd

import pyarrow as pa
import pyarrow.parquet as pq

# %% [markdown]
# # tdrive

# %%
dattaset3 = datasets.load_dataset('szym-on/drive2', split='test')
# Out:
# ...
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset parquet downloaded and prepared to /Users/szymonleszkiewicz/.cache/huggingface/datasets/szym-on___parquet/szym-on--drive2-27e0c4c54f4f6d41/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.

# %%
dattaset3.info
# Out:
# DatasetInfo(description='', citation='', homepage='', license='', features={'taxi_id': Value(dtype='string', id=None), 'date_time': Sequence(feature=Value(dtype='timestamp[us]', id=None), length=-1, id=None), 'lon': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None), 'lat': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None), 'arrays_geometry': Sequence(feature=Sequence(feature=Value(dtype='float64', id=None), length=-1, id=None), length=-1, id=None)}, post_processed=None, supervised_keys=None, task_templates=None, builder_name='parquet', config_name='szym-on--drive2', version=0.0.0, splits={'train': SplitInfo(name='train', num_bytes=758688070, num_examples=8257, shard_lengths=None, dataset_name='parquet'), 'validation': SplitInfo(name='validation', num_bytes=95920120, num_examples=1031, shard_lengths=None, dataset_name='parquet'), 'test': SplitInfo(name='test', num_bytes=83625448, num_examples=1032, shard_lengths=None, dataset_name='parquet')}, dow
# ...

# %%
dattaset3[39].keys()
# Out:
# dict_keys(['taxi_id', 'date_time', 'lon', 'lat', 'arrays_geometry'])

# %%
dattaset3[39]
# Out:
# {'taxi_id': '10296',
#  'date_time': [datetime.datetime(2008, 2, 2, 13, 38, 27),
#   datetime.datetime(2008, 2, 2, 13, 43, 29),
#   datetime.datetime(2008, 2, 2, 13, 48, 31),
#   datetime.datetime(2008, 2, 2, 13, 53, 44),
#   datetime.datetime(2008, 2, 2, 14, 12, 22),
#   datetime.datetime(2008, 2, 2, 14, 17, 24),
#   datetime.datetime(2008, 2, 2, 14, 22, 26),
#   datetime.datetime(2008, 2, 2, 14, 27, 28),
#   datetime.datetime(2008, 2, 2, 14, 40, 54),
#   datetime.datetime(2008, 2, 2, 14, 42, 50),
#   datetime.datetime(2008, 2, 2, 14, 47, 52),
#   datetime.datetime(2008, 2, 2, 14, 52, 54),
#   datetime.datetime(2008, 2, 2, 14, 52, 54),
#   datetime.datetime(2008, 2, 2, 14, 57, 56),
#   datetime.datetime(2008, 2, 2, 15, 11, 22),
#   datetime.datetime(2008, 2, 2, 15, 23, 44),
#   datetime.datetime(2008, 2, 2, 15, 28, 43),
#   datetime.datetime(2008, 2, 2, 15, 33, 45),
#   datetime.datetime(2008, 2, 2, 15, 59, 23),
#   datetime.datetime(2008, 2, 2, 16, 25, 50),
# ...
